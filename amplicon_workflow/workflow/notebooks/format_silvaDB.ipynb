# %%
import pandas as pd
import numpy as np
df = pd.read_csv("/home/nanopore/projects/amplicon_workflow/resources/custom_dbs/silva/taxonomy_split.tsv", sep="\t")

full_species_names = df["genus"] + " " + df["species"]

df["species"] = full_species_names
df["species"] = df["species"].str.replace(";", "")

df.to_csv("/home/nanopore/projects/amplicon_workflow/resources/custom_dbs/silva/taxonomy_split_v2.tsv", sep="\t", index=False)

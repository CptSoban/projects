# %%
import os

def check_augustus(rule):
    if os.path.isdir("/home/marc/projects/Augustus") == True:
        return "o"
    elif os.path.isdir("/home/marc/projects/Augustus") == False and rule == "AUGUSTUS_install":
        return 'touch ("/home/marc/projects/Augustus/done.txt")'
    elif os.path.isdir("/home/marc/projects/Augustus") == False and rule == "BRAKER3":
        return "/home/marc/projects/Augustus/done.txt"

check_augustus("BRAKER3")
check_augustus("AUGUSTUS_install")
# Out:
# 'touch ("/home/marc/projects/Augustus/done.txt")'

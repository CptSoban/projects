# %%
import pandas as pd

read_csv = pd.read_csv("/home/nanopore/projects/rna_seq_workflow/results/20250603_FCOM/functional_annotations/MOT_vs_MOK_combined_annotations.csv")

df = read_csv[["baseMean", "log2FoldChange", "eggnog_Pfam"]]

df.head()

filtered_df = df[df["eggnog_Pfam"] == "Glutaredoxin"]
filtered_df = filtered_df.sort_values(by="baseMean", ascending=False)

filtered_df
# Out:
#          baseMean  log2FoldChange   eggnog_Pfam
# 4040  3397.049134       -0.043319  Glutaredoxin
# 5931  2678.478970       -0.327580  Glutaredoxin
# 5932  2678.478970       -0.327580  Glutaredoxin
# 3040   827.343827        0.075932  Glutaredoxin
